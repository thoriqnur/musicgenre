# %%
import pandas as pd
import numpy as np
import time
import pickle as pkl

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.naive_bayes import MultinomialNB


from learn.classifier import NaiveBayes
from learn.metrics import accuracy, confusion_matrix

# %%
df = pd.read_csv('./data/genres.csv') #import data dari final genres (hanya 4 genres)
print(df.shape) 
df.head()
# Out:
# (1000, 91)
#    chroma_stft_mean_1  chroma_stft_mean_2  chroma_stft_mean_3  \
# 0            0.425068            0.432253            0.471903
# 1            0.746776            0.538205            0.363531
# 2            0.252377            0.186372            0.340461
# 3            0.231209            0.326391            0.474843
# 4            0.169040            0.371378            0.560547
#
#    chroma_stft_mean_4  chroma_stft_mean_5  chroma_stft_mean_6  \
# 0            0.244677            0.307645            0.293240
# 1            0.260683            0.232170            0.274563
# 2            0.477740            0.587381            0.366402
# 3            0.606159            0.786014            0.506588
# 4            0.339455            0.157921            0.435635
#
#    chroma_stft_mean_7  chroma_stft_mean_8  chroma_stft_mean_9  \
# 0            0.271035            0.299862            0.250889
# 1            0.308073            0.396429            0.366760
# ...

# %%
X = df.drop(columns="Target") #semua data kecuali kolom target
y = df["Target"] #hanya colom target
print(X.shape, y.shape)
# print(X, y)
# Out:
# (1000, 90) (1000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
nb_sklearn = MultinomialNB()

min_max_scaler = preprocessing.MinMaxScaler()
X_train_minmax = min_max_scaler.fit_transform(X_train) #normalisasinya disini bray
t_sklearn_start = time.time()
nb_sklearn.fit(X_train_minmax, y_train)
t_sklearn = time.time() - t_sklearn_start

y_pred_sklearn = nb_sklearn.predict(X_test)

acc_sklearn = round(accuracy(y_test, y_pred_sklearn) * 100, 3)

# print("Accuracy using sklearn package\t\t: {0}%, ({1} seconds)".format(acc_sklearn, t_sklearn))
# matrix, label = confusion_matrix(y_test, y_pred_sklearn, show_label=True)
# print(matrix)
# print(label)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-445074e62981> in <module>
#       3 min_max_scaler = preprocessing.MinMaxScaler()
#       4 X_train_minmax = min_max_scaler.fit_transform(X_train) #normalisasinya disini bray
# ----> 5 y_train_minmax = min_max_scaler.fit_transform(y_train)
#       6 t_sklearn_start = time.time()
#       7 nb_sklearn.fit(X_train_minmax, y_train)
#
# c:\users\putri\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ...

# %%
pkl.dump(nb_sklearn, open("modelnew.pkl", "wb"))
